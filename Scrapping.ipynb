# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
from google_play_scraper import app,Sort, reviews_all
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ## Scrapping Data

# %% [markdown]
# Use Reviews_all for scraping data from google_play_scraper to gather reviews data from Google Play Store.

# %%
data = reviews_all(
            'id.go.jakarta.smartcity.jaki',
            sleep_milliseconds = 0,
            lang = 'id',
            country = 'id',
            #sort = Sort.NEWEST,

)

# %%
df = pd.DataFrame(np.array(data), columns = ['review'])
df = df.join(pd.DataFrame(df.pop('review').tolist()))
df
# Out:
#                                   reviewId              userName  \
# 0     50a2a928-2f3f-4ec5-9b73-833d96cefc6e               Noin Ex
# 1     50111c8d-df52-4556-be05-6e0c77672c8f        Fakhri Aldzaky
# 2     dd0c6339-a67b-4b91-8d65-907fd9a21939                 YAHYA
# 3     84729faa-e21e-40b3-95bb-fdcc23840eb7  Ibnu Abdilah muhamed
# 4     2f211d40-75d6-49c6-9d62-ed9cab18f223   Muhammad Ammarrizki
# ...                                    ...                   ...
# 4362  3923a49e-95d4-45fb-a7f1-fc87648f95db       Pengguna Google
# 4363  f61f4186-5dd3-4c2b-8949-941b21f5d0ea       Pengguna Google
# 4364  830acec6-2027-4a1d-b498-30f50d841ca9       Pengguna Google
# 4365  8716aacf-9ada-4b4a-becb-1c1a61570f55       Pengguna Google
# 4366  03efd8ee-3280-4fe0-be9f-66d9951c7dcf       Pengguna Google
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/a-/ALV-U...
# 1     https://play-lh.googleusercontent.com/a/ACg8oc...
# 2     https://play-lh.googleusercontent.com/a/ACg8oc...
# 3     https://play-lh.googleusercontent.com/a-/ALV-U...
# 4     https://play-lh.googleusercontent.com/a-/ALV-U...
# ...                                                 ...
# 4362  https://play-lh.googleusercontent.com/EGemoI2N...
# 4363  https://play-lh.googleusercontent.com/EGemoI2N...
# 4364  https://play-lh.googleusercontent.com/EGemoI2N...
# 4365  https://play-lh.googleusercontent.com/EGemoI2N...
# 4366  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                                 content  score  thumbsUpCount  \
# 0                  SANGAT BAGUS SAAT ERA ANIES BASWEDAN      5              0
# 1     Kalau mw clue diwajibkan foto pakai timestamp ...      1              0
# 2     Wah ga bener nih aplikasi ...sy lapor A yg di ...      1              0
# 3     Tolong buatin laporan pakai vidio juga, kalau ...      1              0
# 4                                             keren loh      5              0
# ...                                                 ...    ...            ...
# 4362                               Mantap, maju Jakarta      5             16
# 4363                                       Jakarta jaya      5              6
# 4364  Coba dulu klo ada tanggapan dari pihak pemprov...      3              6
# 4365                                            Berguna      5              9
# 4366                     Maju kotanya, Bahagia warganya      5             24
#
#      reviewCreatedVersion                  at  \
# 0                  1.2.47 2024-02-17 03:38:50
# 1                    None 2024-02-13 09:48:26
# 2                   3.0.4 2024-02-11 15:24:26
# 3                   3.0.4 2024-02-08 16:16:32
# 4                   3.0.4 2024-02-03 23:20:11
# ...                   ...                 ...
# 4362                1.0.9 2019-11-06 21:14:32
# 4363                 None 2019-11-06 19:49:47
# 4364                 None 2019-11-01 19:19:42
# 4365                1.0.7 2019-10-10 12:43:31
# 4366                1.0.7 2019-09-27 20:14:50
#
#                                            replyContent           repliedAt  \
# 0                                                  None                 NaT
# 1     Halo kak Fakhri, untuk fitur lapor kakak harus... 2024-02-15 09:22:22
# 2     Halo kak Yahya, mohon maaf atas kendala yang d... 2024-02-12 10:29:10
# 3     Halo kak Ibnu, saat ini di aplikasi JAKI sudah... 2024-02-12 10:06:21
# 4     Hi Kak Muhammad Ammarrizki, terima kasih atas ... 2024-02-05 11:06:14
# ...                                                 ...                 ...
# 4362                                               None                 NaT
# 4363                                               None                 NaT
# 4364                                               None                 NaT
# 4365                                               None                 NaT
# 4366                                               None                 NaT
#
#      appVersion
# 0        1.2.47
# 1          None
# 2         3.0.4
# 3         3.0.4
# 4         3.0.4
# ...         ...
# 4362      1.0.9
# 4363       None
# 4364       None
# 4365      1.0.7
# 4366      1.0.7
#
# [4367 rows x 11 columns]

# %% [markdown]
# the 'at' columns were string before, transform it to datetime to further resarch

# %%
df['at']=pd.to_datetime(df['at'])

# %%
df=df.query('at >= "2022-01-01 " and at < "2023-01-01"')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 735 entries, 314 to 1048
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              735 non-null    object
#  1   userName              735 non-null    object
#  2   userImage             735 non-null    object
#  3   content               735 non-null    object
#  4   score                 735 non-null    int64
#  5   thumbsUpCount         735 non-null    int64
#  6   reviewCreatedVersion  577 non-null    object
#  7   at                    735 non-null    datetime64[ns]
#  8   replyContent          673 non-null    object
#  9   repliedAt             673 non-null    datetime64[ns]
#  10  appVersion            577 non-null    object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 68.9+ KB

# %%
df.to_pickle('test.pkl')

# %%
import pickle

# %%
pickle.dump(data,df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12900/4044640143.py in <module>
# ----> 1 pickle.dump(data,df)
#
# TypeError: file must have a 'write' attribute

# %%
df.to_csv('dfs.csv',index=False)
